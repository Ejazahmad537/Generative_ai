# %% [markdown]
# #Image Classification
#
# To use this pipline download the image in PNG format.
#
# Click on the folder icon on the left side panel.
#
# Upload the image and copy its path in the code

# %%
#Displaying the image
from PIL import Image

#Specafy the path to your jpg image
image_path = '/content/dog.png'

#open the image using PIL
image = Image.open(image_path)

#Display the image
image
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=525x510>

# %%
from transformers import pipeline
from PIL import Image

# Specafy the path to your jpg image
image_path = '/content/dog.png'

# open the image using PIL (already done in previous cell, but good for completeness)
# image = Image.open(image_path)

# Try a different model known for general image classification
classifier = pipeline(model="google/vit-base-patch16-224")

# Try running the classifier again
classifier("/content/dog.png")
# Out:
# Fast image processor class <class 'transformers.models.vit.image_processing_vit_fast.ViTImageProcessorFast'> is available for this model. Using slow image processor class. To use the fast image processor class set `use_fast=True`.
# Device set to use cuda:0
# [{'label': 'golden retriever', 'score': 0.9757583141326904},
#  {'label': 'Labrador retriever', 'score': 0.006662316154688597},
#  {'label': 'Chesapeake Bay retriever', 'score': 0.001150502939708531},
#  {'label': 'Sussex spaniel', 'score': 0.001030365820042789},
#  {'label': 'kuvasz', 'score': 0.0008398351492360234}]

# %% [markdown]
# #Stable Diffusion Pipline

# %%
import transformers
from transformers import pipelines
from diffusers import StableDiffusionPipeline
import torch
from huggingface_hub import login

# Log in to Hugging Face Hub
# Replace "hf_your_token_here" with your actual token
# You can also run `huggingface-cli login` in your terminal
login(token="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")

model_id = "runwayml/stable-diffusion-v1-5"

pipe = StableDiffusionPipeline.from_pretrained(model_id, torch_dtype=torch.float16)
pipe= pipe.to("cuda")

prompt = "a Eagle set on mountian"
image = pipe(prompt).images[0]

image.save("Eagle_set_on_mountian.png")

image
# Out:
# ...
#   0%|          | 0/50 [00:00<?, ?it/s]
# <PIL.Image.Image image mode=RGB size=512x512>
